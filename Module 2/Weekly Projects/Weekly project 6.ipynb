# %%
#Program to convert a csv file into numpy arrays

import pandas as pd
import numpy as np
lst=[]
df=pd.read_csv('sample_data/california_housing_test.csv')
for i in df:
  lst.append(df[i])

array=np.array(lst)
print(array)
# Out:
# [[-1.22050e+02 -1.18300e+02 -1.17810e+02 ... -1.19700e+02 -1.17120e+02
#   -1.19630e+02]
#  [ 3.73700e+01  3.42600e+01  3.37800e+01 ...  3.63000e+01  3.41000e+01
#    3.44200e+01]
#  [ 2.70000e+01  4.30000e+01  2.70000e+01 ...  1.00000e+01  4.00000e+01
#    4.20000e+01]
#  ...
#  [ 6.06000e+02  2.77000e+02  4.95000e+02 ...  2.20000e+02  1.40000e+01
#    2.60000e+02]
#  [ 6.60850e+00  3.59900e+00  5.79340e+00 ...  2.28950e+00  3.27080e+00
#    8.56080e+00]
#  [ 3.44700e+05  1.76500e+05  2.70500e+05 ...  6.20000e+04  1.62500e+05
#    5.00001e+05]]
