# %% [markdown]
# #Major Project 1
#
# A program to create a dictionary with product id as
#  the key and product details as values for inventory management system.

# %%
#Initiating two empty dictionary. 
# 1. Main product I'd and value dictionary
# 2. Temporary dictionary for inputting product details.

main_prod={}
temp={}

# %%
#Now inputting product details

id            = input ('Product ID')
temp['name']  = input ('Product Name')
temp['type']  = input ('Product type')
temp['price'] = input ('Product price')
temp['manu']  = input ('Manufacturer')
temp['stock'] = input ('Stock In inventory')

main_prod[id] = temp

print (main_prod)
# Out:
# Product ID1234
# Product NameMacbook
# Product typeLaptop
# Product price70,000
# ManufacturerApple
# Stock In inventory20
# {'1234': {'name': 'Macbook', 'type': 'Laptop', 'price': '70,000', 'manu': 'Apple', 'stock': '20'}}

# %% [markdown]
# Hence a dictionary with product id as key and product details as values is displayed above.
