# %% [markdown]
# #Major Project 2
# ##Library Management System

# %% [markdown]
# 1. Book Database

# %%
#Initializing an dictionary
#1. Main Book dictionary consisting of all the book and it's details.

book={}

# %%
#Creating the book Database

temp={} #Temporary dictionary for inputting book's data

id             = input ('Book ID: ')
temp['name']   = input ('Book Name: ')
temp['quant']  = input ('Quantity of the book: ')
temp['genre']  = input ('Genre: ')
temp['author'] = input ('Author: ')
temp['price']  = input ('Price: ')

book[id] = temp

print (book)
# Out:
# Book ID: 103
# Book Name: Electrical Engineering
# Quantity of the book: 30
# Genre: Educational
# Author: Efgh
# Price: 100
# {'101': {'name': 'Mechanical Engineering ', 'quant': '25', 'genre': 'Educational ', 'author': 'abcd', 'price': '125'}, '102': {'name': 'Automobile Engineering ', 'quant': '20', 'genre': 'Educational ', 'author': 'Xyz', 'price': '100'}, '103': {'name': 'Electrical Engineering ', 'quant': '30', 'genre': 'Educational ', 'author': 'Efgh', 'price': '100'}}

# %% [markdown]
# A book database is established.

# %% [markdown]
# 2. Student Database

# %%
#Initializing the main student dictionary

student={}

# %%
#Creating the student database.

temp={} #Temporary dictionary for inputting student's data
book={} #Temporary dictionary to input issue dates

id             = input ("Enter Student's ID: ")
temp['name']   = input ("Enter Student's Name: ")
temp['g_year'] = input ('Enter grad year: ')
temp['g_deg']  = input ('Enter grad degree: ')
book_id1       = input ('Enter book Id issued: ')
book['issued'] = input ('Enter book issued at date: ')
book['expired']= input ('Enter the issue date expiry of the book: ')
temp[book_id1] =book

student[id]    = temp

print(student)
# Out:
# Enter Student's ID: 11
# Enter Student's Name: Prathamesh
# Enter grad year: 2024
# Enter grad degree: Mechanical
# Enter book Id issued: 101
# Enter book issued at date: 15/11/2022
# Enter the issue date expiry of the book: 15/12/2022
# {'10': {'name': 'Danish', 'g_year': '2023', 'g_deg': 'Automobile ', '102': {'issued': '15/11/2022', 'expired': '15/12/2022'}}, '11': {'name': 'Prathamesh ', 'g_year': '2024', 'g_deg': 'Mechanical ', '101': {'issued': '15/11/2022', 'expired': '15/12/2022'}}}

# %% [markdown]
# Student database with book list along with issued dates is created.
