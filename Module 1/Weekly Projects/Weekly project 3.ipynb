# %%
#A program to create 100 files in a folder named from 'Ashish_1' to 'Ashish_100'

import os
os.mkdir('sample_data/Ashish')

for i in range(1,101):
  name='Ashish_'+str(i)
  fd=open('sample_data/Ashish/'+name+'.txt','w')
  fd.write(name)
  fd.close()
